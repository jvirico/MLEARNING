# %%
import graphlab as gl

# %%
pipes = gl.SFrame.read_csv("Pipes_V1.csv", delimiter=';',header= True)
# Out:
# Finished parsing file /Users/irico/Documents/iPython Notebooks/Pipes_V1.csv
# Parsing completed. Parsed 100 lines in 0.124176 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,str,str,str,str,float,float,float,float,float,float,float,float]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/irico/Documents/iPython Notebooks/Pipes_V1.csv
# Parsing completed. Parsed 13007 lines in 0.085812 secs.

# %%
pipes.head()
# Out:
# Columns:
# 	Super ID	int
# 	OID Line	str
# 	OID Pipeline	str
# 	OID Piperun	str
# 	Pipeline	str
# 	Piperun	str
# 	NPD	float
# 	Lenght	float
# 	X1	float
# 	Y1	float
# 	Z1	float
# 	X2	float
# 	Y2	float
# 	Z2	float
#
# Rows: 10
#
# Data:
# +----------+-------------------------------+-------------------------------+
# | Super ID |            OID Line           |          OID Pipeline         |
# +----------+-------------------------------+-------------------------------+
# |    1     | 000138a5000000000e00d077f2... | 00033457000000000400d077f2... |
# |    2     | 000138a5000000000b008d13b4... | 00033457000000000400d077f2... |
# |    3     | 000138a5000000003600d077f2... | 00033457000000000400d077f2... |
# |    4     | 000138a50000000074002e7ec6... | 00033457000000006a002e7ec6... |
# |    5     | 000138a5000000007f002e7ec6... | 00033457000000006a002e7ec6... |
# |    6     | 000138a500000000d800c65590... | 0003345700000000bb00a766f3... |
# ...

# %%
pipes['Pipeline'].show()

# %%
pipes.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(pipes['X1'],pipes['Y1'],'.')

# %%
len(pipes[pipes['Y1']==0])
# Out:
# 0

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()

# %%
ax = fig.gca(projection='3d')

# %%
pipes[1]['Z1']
# Out:
# 0.0

# %%
ax.plot(pipes[1]['X1'],pipes[1]['Y1'],pipes[1]['Z1'],label='Prueba Pipes S3D')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-59fc3bf53e12> in <module>()
# ----> 1 ax.plot(pipes[1]['X1'],pipes[1]['Y1'],pipes[1]['Z1'],label='Prueba Pipes S3D')
#
# /Users/irico/anaconda/envs/gl-env/lib/python2.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, *args, **kwargs)
#    1537         # Match length
#    1538         if not cbook.iterable(zs):
# -> 1539             zs = np.ones(len(xs)) * zs
#    1540
#    1541         lines = Axes.plot(self, xs, ys, *args[argsi:], **kwargs)
#
# TypeError: object of type 'float' has no len()

# %%
add_spec1 = graphlab.SFrame.read_csv("ADD_SPEC1.txt",delimiter=';',header = True)
# Out:
# Finished parsing file /Users/irico/Documents/iPython Notebooks/ADD_SPEC1.txt
# Parsing completed. Parsed 100 lines in 0.07624 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# ...

# %%
add_spec1.head()
# Out:
# Columns:
# 	CMPNT_ID	int
# 	PROJ_ID	int
# 	SITE_ID	int
# 	CHG_NUM	int
# 	PLANT_ID	int
# 	AREA_ID	int
# 	UNIT_ID	int
# 	CHG_STATUS	str
# 	USER_NAME	str
# 	CHG_DATE	str
# 	SPEC_UDF_C101	str
# 	SPEC_UDF_C102	str
# 	SPEC_UDF_C103	str
# 	SPEC_UDF_C104	str
# 	SPEC_UDF_C105	str
# 	SPEC_UDF_C106	str
# 	SPEC_UDF_C107	str
# 	SPEC_UDF_C108	str
# 	SPEC_UDF_C109	str
# 	SPEC_UDF_C110	int
# 	SPEC_UDF_C111	str
# 	SPEC_UDF_C112	str
# 	SPEC_UDF_C113	str
# 	SPEC_UDF_C114	str
# 	SPEC_UDF_C115	str
# 	SPEC_UDF_C116	str
# 	SPEC_UDF_C117	str
# 	SPEC_UDF_C118	str
# 	SPEC_UDF_C119	str
# 	SPEC_UDF_C120	str
# 	SPEC_UDF_C121	str
# 	SPEC_UDF_C122	str
# 	SPEC_UDF_C123	str
# 	SPEC_UDF_C124	str
# 	SPEC_UDF_C125	str
# 	SPEC_UDF_C126	str
# 	SPEC_UDF_C127	str
# 	SPEC_UDF_C128	str
# 	SPEC_UDF_C129	str
# 	SPEC_UDF_C130	str
# 	SPEC_UDF_C131	str
# 	SPEC_UDF_C132	str
# 	SPEC_UDF_C133	str
# 	SPEC_UDF_C134	str
# 	SPEC_UDF_C135	str
# 	SPEC_UDF_C136	str
# 	SPEC_UDF_C137	str
# 	SPEC_UDF_C138	str
# 	SPEC_UDF_C139	str
# ...
